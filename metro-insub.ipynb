# %%
import pandas as pd

# %%
import numpy as np

# %%
import datetime

# %%
df = pd.read_excel('2019metro.xlsx',header = 1)

# %%
df
# Out:
#                날짜   호선   역번호   역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 0      2019-01-01  1호선   150  서울역  승차     348      321      348      741
# 1      2019-01-01  1호선   150  서울역  하차     222      821      808      961
# 2      2019-01-01  1호선   151   시청  승차      87       98      143      206
# 3      2019-01-01  1호선   151   시청  하차      48      237      323      571
# 4      2019-01-01  1호선   152   종각  승차     669      318      217      203
# ...           ...  ...   ...  ...  ..     ...      ...      ...      ...
# 200799 2019-12-31  8호선  2825   신흥  하차      20       87       86      243
# 200800 2019-12-31  8호선  2826   수진  승차     111      224      542      813
# 200801 2019-12-31  8호선  2826   수진  하차      27       97      115      433
# 200802 2019-12-31  8호선  2827   모란  승차      73       95      342      482
# 200803 2019-12-31  8호선  2827   모란  하차      15       99      140      386
#
#         09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
df[['날짜','역명']]
# Out:
#                날짜   역명
# 0      2019-01-01  서울역
# 1      2019-01-01  서울역
# 2      2019-01-01   시청
# 3      2019-01-01   시청
# 4      2019-01-01   종각
# ...           ...  ...
# 200799 2019-12-31   신흥
# 200800 2019-12-31   수진
# 200801 2019-12-31   수진
# 200802 2019-12-31   모란
# 200803 2019-12-31   모란
#
# [200804 rows x 2 columns]

# %%
my_condition = ['강남', '문래']

# %%
df
# Out:
#                날짜   호선   역번호   역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 0      2019-01-01  1호선   150  서울역  승차     348      321      348      741
# 1      2019-01-01  1호선   150  서울역  하차     222      821      808      961
# 2      2019-01-01  1호선   151   시청  승차      87       98      143      206
# 3      2019-01-01  1호선   151   시청  하차      48      237      323      571
# 4      2019-01-01  1호선   152   종각  승차     669      318      217      203
# ...           ...  ...   ...  ...  ..     ...      ...      ...      ...
# 200799 2019-12-31  8호선  2825   신흥  하차      20       87       86      243
# 200800 2019-12-31  8호선  2826   수진  승차     111      224      542      813
# 200801 2019-12-31  8호선  2826   수진  하차      27       97      115      433
# 200802 2019-12-31  8호선  2827   모란  승차      73       95      342      482
# 200803 2019-12-31  8호선  2827   모란  하차      15       99      140      386
#
#         09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
df['역명'].isin(my_condition)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 200799    False
# 200800    False
# 200801    False
# 200802    False
# 200803    False
# Name: 역명, Length: 200804, dtype: bool

# %%
df=df.loc[ df['역명'].isin(my_condition) ]

# %%
station=df.loc[ df['역명'].isin(my_condition) ]

# %%
station
# Out:
#                날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 62     2019-01-01  2호선  222  강남  승차    1612     1425      852      742
# 63     2019-01-01  2호선  222  강남  하차     160      719      733     1064
# 88     2019-01-01  2호선  235  문래  승차     102      144      138      219
# 89     2019-01-01  2호선  235  문래  하차      57      166      177      283
# 612    2019-01-02  2호선  222  강남  승차     366      813     1881     3288
# ...           ...  ...  ...  ..  ..     ...      ...      ...      ...
# 199789 2019-12-30  2호선  235  문래  하차      66      395     1411     5443
# 200314 2019-12-31  2호선  222  강남  승차     609      889     1685     2505
# 200315 2019-12-31  2호선  222  강남  하차     500     1761     5269    13006
# 200340 2019-12-31  2호선  235  문래  승차     124      386     1567     1688
# 200341 2019-12-31  2호선  235  문래  하차      68      355     1226     5032
#
#         09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
#1번 완료

# %%
#2번 1월의 데이터만 선택하기

# %%
station
# Out:
#                날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 62     2019-01-01  2호선  222  강남  승차    1612     1425      852      742
# 63     2019-01-01  2호선  222  강남  하차     160      719      733     1064
# 88     2019-01-01  2호선  235  문래  승차     102      144      138      219
# 89     2019-01-01  2호선  235  문래  하차      57      166      177      283
# 612    2019-01-02  2호선  222  강남  승차     366      813     1881     3288
# ...           ...  ...  ...  ..  ..     ...      ...      ...      ...
# 199789 2019-12-30  2호선  235  문래  하차      66      395     1411     5443
# 200314 2019-12-31  2호선  222  강남  승차     609      889     1685     2505
# 200315 2019-12-31  2호선  222  강남  하차     500     1761     5269    13006
# 200340 2019-12-31  2호선  235  문래  승차     124      386     1567     1688
# 200341 2019-12-31  2호선  235  문래  하차      68      355     1226     5032
#
#         09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
station=station.head(125) #1월 불러오는거 트루값 구현했지만 뺴오기가 부족해서 
#그냥 페이지로 저장하기

# %%
station
# Out:
#               날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 62    2019-01-01  2호선  222  강남  승차    1612     1425      852      742
# 63    2019-01-01  2호선  222  강남  하차     160      719      733     1064
# 88    2019-01-01  2호선  235  문래  승차     102      144      138      219
# 89    2019-01-01  2호선  235  문래  하차      57      166      177      283
# 612   2019-01-02  2호선  222  강남  승차     366      813     1881     3288
# ...          ...  ...  ...  ..  ..     ...      ...      ...      ...
# 16562 2019-01-31  2호선  222  강남  승차     437      846     1929     3146
# 16563 2019-01-31  2호선  222  강남  하차     513     2001     7347    15578
# 16588 2019-01-31  2호선  235  문래  승차     140      433     2045     2150
# 16589 2019-01-31  2호선  235  문래  하차      81      484     1254     5401
# 17112 2019-02-01  2호선  222  강남  승차     475      846     1912     3067
#
#        09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
# 1번까지
#station['날짜']
#pd.to_datetime(df['날짜'])
#station['날짜'] = pd.to_datetime(df['날짜'])
#station['날짜']
#station['날짜'].dt.month

# %%
station.iloc[:, 5: 25] # 시간별 이용정보 데이터 불러오기
# Out:
#        06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  10 ~ 11  11 ~ 12  12 ~ 13  \
# 62       1612     1425      852      742      731      953     1197     1346
# 63        160      719      733     1064     1755     1582     1898     2571
# 88        102      144      138      219      247      326      359      392
# 89         57      166      177      283      378      267      292      374
# 612       366      813     1881     3288     2441     2426     3314     4091
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 16562     437      846     1929     3146     2524     2233     3163     3888
# 16563     513     2001     7347    15578    15153     6870     5707     5322
# 16588     140      433     2045     2150     1078      795      786      883
# 16589      81      484     1254     5401     2519     1014      783      829
# 17112     475      846     1912     3067     2416     2484     3544     4615
#
# ...

# %%
station.sum(axis=1) # 각 역의 승하차 인원 시간별 정보
# Out:
# 62        77966
# 63        73646
# 88        11943
# 89        12735
# 612      233744
#           ...
# 16562    234090
# 16563    234978
# 16588     48329
# 16589     49185
# 17112    243602
# Length: 125, dtype: int64

# %%
station.mean(axis=1) # 각 역의 시간대별 승하차 평균값
# Out:
# /home/mato/anaconda3/envs/opencv4/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# 62        3543.909091
# 63        3347.545455
# 88         542.863636
# 89         578.863636
# 612      10624.727273
#              ...
# 16562    10640.454545
# 16563    10680.818182
# 16588     2196.772727
# 16589     2235.681818
# 17112    11072.818182
# Length: 125, dtype: float64

# %%
station.sort_index(axis=1, ascending=False) #내림차순정렬
station.head(1) #사람이 가장 많이 이용한 강남역의 날
# Out:
#            날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  \
# 62 2019-01-01  2호선  222  강남  승차    1612     1425      852      742      731
#
#     ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  22 ~ 23  \
# 62  ...     2596     3095     3067     2696     3159     3638     3987
#
#     23 ~ 24  24시 이후    합 계
# 62     1772       0  38872
#
# [1 rows x 26 columns]

# %%
station.tail(1) # 사람이 가장 적게 이용한 문래역의 날 데이터
# Out:
#               날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 17112 2019-02-01  2호선  222  강남  승차     475      846     1912     3067
#
#        09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# 17112     2416  ...    10053    12911    15017     9498     7691     9062
#
#        22 ~ 23  23 ~ 24  24시 이후     합 계
# 17112     9920     5514    1280  121690
#
# [1 rows x 26 columns]

# %%
df #강남문래
# Out:
#                날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 62     2019-01-01  2호선  222  강남  승차    1612     1425      852      742
# 63     2019-01-01  2호선  222  강남  하차     160      719      733     1064
# 88     2019-01-01  2호선  235  문래  승차     102      144      138      219
# 89     2019-01-01  2호선  235  문래  하차      57      166      177      283
# 612    2019-01-02  2호선  222  강남  승차     366      813     1881     3288
# ...           ...  ...  ...  ..  ..     ...      ...      ...      ...
# 199789 2019-12-30  2호선  235  문래  하차      66      395     1411     5443
# 200314 2019-12-31  2호선  222  강남  승차     609      889     1685     2505
# 200315 2019-12-31  2호선  222  강남  하차     500     1761     5269    13006
# 200340 2019-12-31  2호선  235  문래  승차     124      386     1567     1688
# 200341 2019-12-31  2호선  235  문래  하차      68      355     1226     5032
#
#         09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
df1=df.loc[:, ['07 ~ 08', '08 ~ 09']] # 7~9시 데이터정보를 df1로 선언

# %%
df1
# Out:
#         07 ~ 08  08 ~ 09
# 62          852      742
# 63          733     1064
# 88          138      219
# 89          177      283
# 612        1881     3288
# ...         ...      ...
# 199789     1411     5443
# 200314     1685     2505
# 200315     5269    13006
# 200340     1567     1688
# 200341     1226     5032
#
# [1460 rows x 2 columns]

# %%
df1.mean(axis=1) # 7~9 까지의 평균값
# Out:
# 62         797.0
# 63         898.5
# 88         178.5
# 89         230.0
# 612       2584.5
#            ...
# 199789    3427.0
# 200314    2095.0
# 200315    9137.5
# 200340    1627.5
# 200341    3129.0
# Length: 1460, dtype: float64

# %%
df
# Out:
#                날짜   호선  역번호  역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 62     2019-01-01  2호선  222  강남  승차    1612     1425      852      742
# 63     2019-01-01  2호선  222  강남  하차     160      719      733     1064
# 88     2019-01-01  2호선  235  문래  승차     102      144      138      219
# 89     2019-01-01  2호선  235  문래  하차      57      166      177      283
# 612    2019-01-02  2호선  222  강남  승차     366      813     1881     3288
# ...           ...  ...  ...  ..  ..     ...      ...      ...      ...
# 199789 2019-12-30  2호선  235  문래  하차      66      395     1411     5443
# 200314 2019-12-31  2호선  222  강남  승차     609      889     1685     2505
# 200315 2019-12-31  2호선  222  강남  하차     500     1761     5269    13006
# 200340 2019-12-31  2호선  235  문래  승차     124      386     1567     1688
# 200341 2019-12-31  2호선  235  문래  하차      68      355     1226     5032
#
#         09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
print(df['날짜'])
# Out:
# 62       2019-01-01
# 63       2019-01-01
# 88       2019-01-01
# 89       2019-01-01
# 612      2019-01-02
#             ...
# 199789   2019-12-30
# 200314   2019-12-31
# 200315   2019-12-31
# 200340   2019-12-31
# 200341   2019-12-31
# Name: 날짜, Length: 1460, dtype: datetime64[ns]

# %%
#5 번은 PASS
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-274-32efc6bdbac2> in <module>
# ----> 1 dates = df['날짜'].np.split('-')
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'np'
